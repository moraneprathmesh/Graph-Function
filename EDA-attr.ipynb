# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dat=pd.read_csv('attrition.csv')
dat.head()
# Out:
#    s.no  Age  Attrition     BusinessTravel              Department  \
# 0     1   41          1      Travel_Rarely                   Sales
# 1     2   49          0  Travel_Frequently  Research & Development
# 2     3   37          1      Travel_Rarely  Research & Development
# 3     4   33          0  Travel_Frequently  Research & Development
# 4     5   27          0      Travel_Rarely  Research & Development
#
#   EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0  Life Sciences                        2  Female               3         2
# 1  Life Sciences                        3    Male               2         2
# 2          Other                        4    Male               2         1
# 3  Life Sciences                        4  Female               3         1
# 4        Medical                        1    Male               3         1
#
#    ...  MaritalStatus MonthlyIncome  OverTime TotalWorkingYears  \
# ...

# %%
dat.columns
# Out:
# Index(['s.no', 'Age', 'Attrition', 'BusinessTravel', 'Department',
#        'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome',
#        'OverTime', 'TotalWorkingYears', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'DistanceFromHome'],
#       dtype='object')

# %%
dat.boxplot()
# Out:
# <AxesSubplot:>

# %%
dat.isna().sum()
# Out:
# s.no                       0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# EducationField             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# OverTime                   0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# DistanceFromHome           0
# dtype: int64

# %%
dat.dtypes
# Out:
# s.no                        int64
# Age                         int64
# Attrition                   int64
# BusinessTravel             object
# Department                 object
# EducationField             object
# EnvironmentSatisfaction     int64
# Gender                     object
# JobInvolvement              int64
# JobLevel                    int64
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# OverTime                   object
# TotalWorkingYears           int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# DistanceFromHome            int64
# dtype: object

# %% [raw]
# Attrition, Business travel, Department, Education field, Gender, Jobinvolment, Marital status, Overtime are categorical variables

# %%
dat.describe()
# Out:
#               s.no          Age    Attrition  EnvironmentSatisfaction  \
# count  1470.000000  1470.000000  1470.000000              1470.000000
# mean    735.500000    36.923810     0.161224                 2.721769
# std     424.496761     9.135373     0.367863                 1.093082
# min       1.000000    18.000000     0.000000                 1.000000
# 25%     368.250000    30.000000     0.000000                 2.000000
# 50%     735.500000    36.000000     0.000000                 3.000000
# 75%    1102.750000    43.000000     0.000000                 4.000000
# max    1470.000000    60.000000     1.000000                 4.000000
#
#        JobInvolvement     JobLevel  JobSatisfaction  MonthlyIncome  \
# count     1470.000000  1470.000000      1470.000000    1470.000000
# mean         2.729932     2.063946         2.728571    6502.931293
# std          0.711561     1.106940         1.102846    4707.956783
# ...

# %%
dat.drop(['s.no'],axis=1).hist(bins = 30, figsize= (10, 10), color = 'b')
plt.show()

# %%
dat.drop(['s.no'],axis=1)
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      41          1      Travel_Rarely                   Sales
# 1      49          0  Travel_Frequently  Research & Development
# 2      37          1      Travel_Rarely  Research & Development
# 3      33          0  Travel_Frequently  Research & Development
# 4      27          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 1465   36          0  Travel_Frequently  Research & Development
# 1466   39          0      Travel_Rarely  Research & Development
# 1467   27          0      Travel_Rarely  Research & Development
# 1468   49          0  Travel_Frequently                   Sales
# 1469   34          0      Travel_Rarely  Research & Development
#
#      EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0     Life Sciences                        2  Female               3
# ...

# %%
dat.groupby('Attrition')['Attrition'].count().plot(kind='bar',rot=0)
plt.show()

# %%
corr=dat.corr()
corr.Attrition
# Out:
# s.no                      -0.010369
# Age                       -0.159205
# Attrition                  1.000000
# EnvironmentSatisfaction   -0.103369
# JobInvolvement            -0.130016
# JobLevel                  -0.169105
# JobSatisfaction           -0.103481
# MonthlyIncome             -0.159840
# TotalWorkingYears         -0.171063
# WorkLifeBalance           -0.063939
# YearsAtCompany            -0.134392
# YearsInCurrentRole        -0.160545
# YearsSinceLastPromotion   -0.033019
# YearsWithCurrManager      -0.156199
# DistanceFromHome           0.077924
# Name: Attrition, dtype: float64

# %% [markdown]
# except distance from home rest all columns have negative correlation with attrition
#
# here monthly income, total working years, years at company, years in current role, years since last promotion, and distance from home are numerical variables rest are categorical variables
#
# for categorical we will analyze all attributes relation with attrition through visualisation in bivariate

# %%
dat[['Gender','Attrition']].groupby(['Gender']).mean()
#attrition rate is higher in males
# Out:
#         Attrition
# Gender
# Female   0.147959
# Male     0.170068

# %%
dat[['Gender','Attrition']].groupby(['Gender']).mean().plot(kind='bar', figsize=(4,4), fontsize=12,rot=45)
plt.xlabel('Gender',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition Rate With Resp To Gender',fontsize=14)
plt.show()
#higher attrition in males visible from graph

# %%
dat.groupby('EducationField').size().plot(kind='pie', autopct='%.2f')
plt.title('EducationField breakup',fontsize=14)
plt.show()
dat.groupby(['EducationField'])['Attrition'].mean().plot(kind='bar', figsize=(4,4), fontsize=12)
plt.xlabel('EducationField',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To EducationField',fontsize=14)
plt.show()
#while there are very few people of hr and technical degree but there attrition rate is quiet high may be these people are not satisfied with work in company

# %%
dat.groupby('Department').size().plot(kind='pie', autopct='%.2f')
plt.title('Department',fontsize=14)
plt.show()
dat.groupby(['Department'])['Attrition'].mean().plot(kind='bar', figsize=(4,4), fontsize=12)
plt.xlabel('Department',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To Department',fontsize=14)
plt.show()
#similarly in this also attrtion is high in dept sales and hr

# %%
dat.groupby('BusinessTravel').size().plot(kind='pie', autopct='%.2f')
plt.title('BusinessTravel breakup',fontsize=14)
plt.show()
dat.groupby(['BusinessTravel'])['Attrition'].mean().plot(kind='bar', figsize=(4,4), fontsize=12,rot=45)
plt.xlabel('BusinessTravel',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To BusinessTravel',fontsize=14)
plt.show()
#travel frequently(which is 20% of total employees) is having very high attrition rate which is 25%

# %%
dat.groupby('OverTime').size().plot(kind='pie', autopct='%.2f')
plt.title('OverTime breakup',fontsize=14)
plt.show()
dat.groupby(['OverTime'])['Attrition'].mean().plot(kind='bar', figsize=(4,4), fontsize=12)
plt.xlabel('OverTime',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To OverTime',fontsize=14)
plt.show()
# attrition rate of people which are made to do overtime is very high around 30 % which is aroung 60% percent of total employess left

# %%
dat.groupby(['MaritalStatus'])['Attrition'].mean().plot(kind='bar', figsize=(4,4), fontsize=12,rot=45)
plt.xlabel('MaritalStatus',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To MaritalStatus',fontsize=14)
plt.show()
#single poeple have very attrition rate which around 25%

# %%
dat.groupby('JobLevel').size().plot(kind='pie', autopct='%.2f')
plt.title('JobLevel breakup',fontsize=14)
plt.show()
dat.groupby(['JobLevel'])['Attrition'].mean().plot(kind='bar', figsize=(4,4), fontsize=12,rot=0)
plt.xlabel('JobLevel',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To JobLevel',fontsize=14)
plt.show()
# lower job level employees have higher attrition rate

# %%
dat.groupby(['EnvironmentSatisfaction'])['Attrition'].mean().plot(kind='bar', figsize=(4,4), fontsize=12,rot=0)
plt.xlabel('EnvironmentSatisfaction',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To EnvironmentSatisfaction',fontsize=14)
plt.show()
#similarly in enviromnetsatisfaction there is negative correlation between attrition and environmentsatisfaction
dat.groupby('EnvironmentSatisfaction').size().plot(kind='pie', autopct='%.2f')
plt.title('EnvironmentSatisfaction breakup',fontsize=14)
plt.show()
#so there are one third people who left company belong to envn satis rating

# %%
dat[['Attrition','JobSatisfaction']].groupby(['JobSatisfaction']).mean().plot(kind='bar', figsize=(4,4), fontsize=12,rot=0)
plt.xlabel('JobSatisfaction',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition Rate With Resp To Jobsatisfaction',fontsize=14)
plt.show()
#less is the job satisfaction level higher is attrition
# only job satisfaction 4 has below average attrition in the company (other levels of satisfaction have around avg or more than that)

# %%
dat.groupby(['WorkLifeBalance'])['Attrition'].mean().plot(kind='bar', figsize=(6,6), fontsize=12,rot=0)
plt.xlabel('WorkLifeBalance',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To WorkLifeBalance',fontsize=14)
plt.show()

# %%
dat.groupby(['YearsSinceLastPromotion'])['Attrition'].mean().plot(kind='bar',figsize=(10,8), fontsize=12,rot=0)
plt.xlabel('YearsSinceLastPromotion',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To YearsSinceLastPromotion',fontsize=14)
plt.show()
#no proper correlation could be seen in attrtion and years since promotion

# %%
dat.groupby(['YearsInCurrentRole'])['Attrition'].mean().plot(kind='bar', figsize=(10,8), fontsize=12)
plt.xlabel('YearsInCurrentRole',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To YearsInCurrentRole',fontsize=14)
plt.show()
# in less than an year in promotion the attrition is high may be employees wait for promotion in a company and then apply for switch

# %%
dat.groupby(['YearsAtCompany'])['Attrition'].mean().plot(kind='bar', figsize=(12,8), fontsize=12)
plt.xlabel('YearsAtCompany',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To YearsAtCompany',fontsize=14)
plt.show()

# %%
dat.groupby(['Age'])['Attrition'].mean().plot(kind='bar', figsize=(14,8), fontsize=12)
plt.xlabel('Age',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To Age',fontsize=14)
plt.show()
# young people have high attrition rate

# %%
dat.groupby(['DistanceFromHome'])['Attrition'].mean().plot(kind='bar', figsize=(12,8), fontsize=12,rot=0)
plt.xlabel('DistanceFromHome',fontsize=12)
plt.ylabel('Attrition rate',fontsize=12)
plt.title('Attrition With Resp To DistanceFromHome',fontsize=14)
plt.show()
#people with higher distance from home are more prone to attrition which is also visible from positive corr with attrition

# %%
sns.kdeplot(dat_a['MonthlyIncome'], label = 'Employee left', color = 'red', )
sns.kdeplot(dat_n['MonthlyIncome'], label = 'Employee stay', color = 'blue')
plt.show()
#https://mathisonian.github.io/kde/
#people with salary lower than 5000 are more likely to leave the company

# %%
corr=dat.corr()
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_1fc97_row0_col0, #T_1fc97_row1_col1, #T_1fc97_row2_col2, #T_1fc97_row3_col3, #T_1fc97_row4_col4, #T_1fc97_row5_col5, #T_1fc97_row6_col6, #T_1fc97_row7_col7, #T_1fc97_row8_col8, #T_1fc97_row9_col9, #T_1fc97_row10_col10, #T_1fc97_row11_col11, #T_1fc97_row12_col12, #T_1fc97_row13_col13, #T_1fc97_row14_col14 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_1fc97_row0_col1, #T_1fc97_row0_col7, #T_1fc97_row0_col13, #T_1fc97_row6_col8, #T_1fc97_row14_col10 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_1fc97_row0_col2, #T_1fc97_row9_col13, #T_1fc97_row13_col4 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_1fc97_row0_col3, #T_1fc97_row6_col13, #T_1fc97_row8_col4, #T_1fc97_row11_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_1fc97_row0_col4, #T_1fc97_row0_col10, #T_1fc97_row3_col4, #T_1fc97_row11_col9, #T_1fc97_row12_col3 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# ...

# %%
import seaborn as sns
sns.heatmap(dat annote=True)
# Out:
#   File "C:\Users\SHIMAN~1\AppData\Local\Temp/ipykernel_11200/3068255301.py", line 2
#     sns.heatmap(dat annote=True)
#                     ^
# SyntaxError: invalid syntax

# %% [raw]
# from bivariate analysis with our target variable we found out that
# overtime, job level, monthly income, higher distance from home, marital status, job satisfaction, enviroment, worklife balance, business travel, deparment, gender are the attributes on which attrn depnds
# whereas job level, monthly income age are highly correlated so we can do pca for these correlated attributes while making model
# so attr is depn on ((age,monthly income, job level), marital status, job satisfaction, env satis, worklife,  buisness travel, overtime and gender)

# %%
dat.groupby(['BusinessTravel','JobLevel','OverTime'])['Attrition'].mean()
#if we check attrition rate considering 4 attributes togeather which are marital status, job role, travel and overtime
#we can see if job level =1, overtime is yes, travel is frequent, and marital status is single- attrition is as high as 75%
# if travelling is rare and rest all factors are same then also attrition is around 65%
# if overtime is no rest all factors are same then also attrition is quite high around 50%
# Out:
# BusinessTravel     JobLevel  OverTime
# Non-Travel         1         No          0.050000
#                              Yes         0.500000
#                    2         No          0.038462
#                              Yes         0.066667
#                    3         No          0.071429
#                              Yes         0.166667
#                    4         No          0.000000
#                              Yes         0.200000
#                    5         No          0.000000
#                              Yes         0.000000
# Travel_Frequently  1         No          0.292308
#                              Yes         0.666667
#                    2         No          0.102564
#                              Yes         0.269231
#                    3         No          0.133333
#                              Yes         0.200000
#                    4         No          0.166667
#                              Yes         0.142857
# ...

# %%
dat.groupby('Attrition').size().plot(kind='pie', autopct='%.2f', colour=my_colours)
my_colours=[]
plt.title('Attrition breakup',fontsize=14)
plt.show()
